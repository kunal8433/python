# %% [markdown]
# # Welcome to numpy

# %%
import numpy as np

# %%
my = np.array ([3,3,4,5])

# %%
my  [0]
# Out:
# np.int64(3)

# %%
my.dtype
# Out:
# dtype('int64')

# %%
my.dtype
# Out:
# dtype('int64')

# %%
for i in range (19 , 32)
# Out:
#   Cell In[27], line 1
#     for i in range (19 , 32)
#                             ^
# SyntaxError: expected ':'

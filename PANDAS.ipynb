# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
       "name" : ['kunal','lucky','ankit'],
       "age" : [ 17 ,14 , 23 ],
       "city" : [ 'meerut' , 'meerut' , 'meerut' ]


}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#     name  age    city
# 0  kunal   17  meerut
# 1  lucky   14  meerut
# 2  ankit   23  meerut

# %%
df.to_csv('brothers.csv')

# %%
df.to_csv('brothers_index_false.csv' , index = False)

# %%
df.head (1)
# Out:
#     name  age    city
# 0  kunal   17  meerut

# %%
df.tail(1)
# Out:
#     name  age    city
# 2  ankit   23  meerut

# %%
df
# Out:
#     name  age    city
# 0  kunal   17  meerut
# 1  lucky   14  meerut
# 2  ankit   23  meerut
